# %% [markdown]
# <a href="https://colab.research.google.com/github/Brachaglazer/Module14_Bracha_Glazer/blob/main/Tuples_Downey_Rebuilt_STUDENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Tuples — Chapter (Downey‑Aligned, No Dictionaries)
#
# **Support Chapter + Exercises**
# _Based on Allan Downey’s Tuples chapter, rewritten to avoid dictionaries._
#
# This notebook:
# - Uses only concepts you have already learned
# - Preserves the intent of Downey’s original exercises
# - Contains **NO solutions** — student work only
#
# ---

# %% [markdown]
# ## 1️⃣ Tuples
#
# A **tuple** is an ordered, immutable collection of values.
#
# - **Ordered**: elements have positions
# - **Immutable**: elements cannot be changed after creation
#
# Examples:
# - `(3, 7, 10)`
# - `(1, "apple", 3.14)`

# %%
# Run this cell

t = (3, 7, 10)
t
# Out:
# (3, 7, 10)

# %% [markdown]
# ## 2️⃣ Tuples vs Lists
#
# | Feature | List | Tuple |
# |-------|------|-------|
# | Mutable | Yes | No |
# | Syntax | `[ ]` | `( )` |
# | Best for fixed data | No | Yes |
#
# Once created, tuple values cannot be reassigned.

# %%
# Lists are mutable
lst = [1, 2, 3]
lst[0] = 99
lst
# Out:
# [99, 2, 3]

# %%
# Tuples are immutable
tup = (1, 2, 3)
tup[0] = 99  # Uncomment to observe the error
tup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1223125669.py in <cell line: 0>()
#       1 # Tuples are immutable
#       2 tup = (1, 2, 3)
# ----> 3 tup[0] = 99  # Uncomment to observe the error
#       4 tup
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 3️⃣ Creating Tuples
#
# ### Multiple elements
# `t = (4, 5, 6)`
#
# ### Single‑element tuples
# A single‑element tuple **must** include a trailing comma.

# %%
single_ok = (5,)
single_not = (5)

(type(single_ok), type(single_not))
# Out:
# (tuple, int)

# %% [markdown]
# ## 4️⃣ Indexing and Slicing
#
# Tuples support indexing and slicing, just like strings and lists.

# %%
t = ('a', 'b', 'c', 'd')

# Try indexing and slicing
#t[0]
#t[-1]
t[1:3]
# Out:
# ('b', 'c')

# %% [markdown]
# ## 5️⃣ Looping Through Tuples
#
# You can loop through tuples using a `for` loop.

# %%
values = (10, 20, 30)

for value in values:
  print(value)

# TODO: loop and print each value
# Out:
# 10
# 20
# 30

# %% [markdown]
# ## 6️⃣ Tuple Assignment (Unpacking)
#
# Tuples allow multiple assignment in one statement.

# %%
# TODO: unpack the tuple into two variables
pair = (3, 7)

a, b = pair
print(a)
print(b)
# Out:
# 3
# 7

# %% [markdown]
# ## 7️⃣ Functions That Return Tuples
#
# A function can return multiple values as a tuple.

# %%
# TODO: write a function that returns the minimum and maximum

def min_max(numbers):
  minimum = min(numbers)
  maximum = max(numbers)
  return minimum, maximum

# Test
data = [4, 2, 9]
result = min_max(data)
print(result)
# Out:
# (2, 9)

# %% [markdown]
# ## 8️⃣ Tuples Inside Lists
#
# Tuples can be stored inside lists to group related values.

# %%
points = [(1, 2), (3, 4), (5, 6)]
for pair in points:
  print(pair)

# TODO: loop through the list and print each x, y pair
# Out:
# (1, 2)
# (3, 4)
# (5, 6)

# %% [markdown]
# # 🧪 Exercises (Downey‑Inspired, List‑Based)
#
# Complete all exercises below. Do **not** use dictionaries.
#
# ---

# %% [markdown]
# ## Exercise 1 — Most Frequent Characters
#
# Write a function `most_frequent(s)` that:
# - counts how many times each character appears
# - stores results as a **list of (character, count) tuples**
# - prints the characters in decreasing order of frequency
# - use : sorted(nums, reverse=True)

# %%
def most_frequent(s):
    # TODO: use a list of tuples (no dictionaries)
    tuple_list = []
    word = tuple(s)
    for letter in word:
      nums = word.count(letter)
      if (nums, letter) not in tuple_list:
        tuple_list.append((nums, letter))
    sort_list = sorted(tuple_list, reverse=True)
    for row in sort_list:
      print(row[1])

# Test string
most_frequent('banana')
# Out:
# a
# n
# b

# %% [markdown]
# ## Exercise 2 — Word Frequencies
#
# Given a list of words, count how often each word appears.
# Return a list of `(word, count)` tuples sorted by count (descending).
# - use : sorted(nums, reverse=True)

# %%
def word_frequencies(words):
  word_list = []
  for letter in words:
    nums = words.count(letter)
    if (nums, letter) not in word_list:
      word_list.append((nums, letter))
  return sorted(word_list, reverse=True)

words = ['the', 'cat', 'the', 'dog']
print(word_frequencies(words))
# Out:
# [(2, 'the'), (1, 'dog'), (1, 'cat')]

# %% [markdown]
# ## Exercise 3 — Most Common Item
#
# Write a function that takes a list of `(item, count)` tuples
# and returns the tuple with the highest count.

# %%
def most_common(counts):
  maxi = None
  for row in counts:
    count = 0
    for col in row:
      if count > 0:
        if maxi == None or col > maxi:
          maxi = col
          max_row = row
      else:
        count += 1
        continue
  return max_row

counts = [("Apple", 5), ("Banana", 6), ("Cookie", 3)]
maximum = most_common(counts)
print(maximum)
# Out:
# ('Banana', 6)

# %% [markdown]
# # ✅ Honor Attestation
#
# At the bottom of your notebook, write:
#
# - I read and interacted with the chapter content.
# - I completed the exercises independently.
# - I did not use AI or unauthorized resources during the timed portion.
#
# **Time spent:** _____ minutes

# %% [markdown]
# I read and interacted with the chapter content.
# I completed the exercises independently.
# I did not use AI or unauthorized resources during the timed portion.
# Time spent: _____ minutes - I am really unsure but probably over an hour.

# %% [markdown]
# Read and interact with the above chapter
#
# Completed all required exercises
#
# Timed yourself in a quiet, test-appropriate environment - For a bit of it I was unable to do it in a quiet place but I obviously did not discuss the contents of the quiz I was taking.
#
# ⏱️ How much time did you spend completing the exercises?
# Probably over an hour, but I don't know exactly.
#
# 🤖 Did you use AI while learning the chapter?
# No.
#
# If yes, did it help you understand the material?
#
# 🧠 Any reflections you would like to share:
#
# How did the quiz feel?
# It was a bit more challenging than the others.
#
# How confident do you feel relative to the Final Exam?
# I think with more practice it will be good iyH.
#
# Any areas where you feel strong or uncertain?
# I need to review the methods.
